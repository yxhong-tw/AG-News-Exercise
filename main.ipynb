# %%
configs = {}


# Basic related settings
configs['version'] = 'formal-2'
configs['version_message'] = ''
configs['logging_time'] = 1500
configs['drive_path'] = '/content/drive'
configs['AGNews_path'] = (
    configs['drive_path'] 
    + '/Othercomputers/Pulsar-MSI/Workspace/NCKU/IKM_Lab/AG-News-Exercise'
)
# configs['AGNews_path'] = '.'


# Training related settings
configs['epoch'] = 5
configs['batch_size'] = 16

## Model related settings
configs['model_name'] = 'BertWithSingleNN'
# configs['model_name'] = 'BertWithMultiNNs'
configs['hidden_size'] = 768
configs['class_number'] = 4
configs['nn_layer_number'] = 3
configs['n_factor'] = 0.5
configs['freeze_lm'] = False

### Checkpoint related settings
configs['load_checkpoint'] = False
configs['checkpoint_epoch'] = -1

## Optimizer related settings
configs['optimizer_name'] = 'Adam'
configs['optimizer_lr'] = 1e-5

## Scheduler related settings
configs['scheduler_name'] = 'ReduceLROnPlateau'
configs['scheduler_mode'] = 'min'
configs['scheduler_factor'] = 0.1
configs['scheduler_patience'] = 2
configs['scheduler_verbose'] = True

## Data related settings
configs['dataset_name'] = 'AGNewsDataset'
configs['formatter_name'] = 'AGNewsFormatter'
configs['max_sequence_len'] = 512
configs['dataloader_shuffle'] = True

# %%
import os

from google.colab import drive


drive.mount(configs['drive_path'], force_remount=True)

os.chdir(configs['AGNews_path'])
# Out:
# Mounted at /content/drive

# %%
# !pip install -r requirements.txt
# Out:
# Collecting transformers (from -r requirements.txt (line 1))
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 15.8 MB/s eta 0:00:00
# Collecting wandb (from -r requirements.txt (line 2))
#   Downloading wandb-0.15.7-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 31.7 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers->-r requirements.txt (line 1))
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->-r requirements.txt (line 1))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->-r requirements.txt (line 1))
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 51.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 2)) (8.1.6)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->-r requirements.txt (line 2))
#   Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 2)) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb->-r requirements.txt (line 2))
#   Downloading sentry_sdk-1.28.1-py2.py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.7/214.7 kB 19.9 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb->-r requirements.txt (line 2))
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb->-r requirements.txt (line 2))
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb->-r requirements.txt (line 2))
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 2)) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 2)) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb->-r requirements.txt (line 2)) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 2))
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->-r requirements.txt (line 1)) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->-r requirements.txt (line 1)) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (3.4)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 2))
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=c1bb10bbce8c2d86f597b0f0c8dd6dfcf683efda4ca8e357e2cffda8a4966bca
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: tokenizers, safetensors, pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, huggingface-hub, gitdb, transformers, GitPython, wandb
# Successfully installed GitPython-3.1.32 docker-pycreds-0.4.0 gitdb-4.0.10 huggingface-hub-0.16.4 pathtools-0.1.2 safetensors-0.3.1 sentry-sdk-1.28.1 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.13.3 transformers-4.31.0 wandb-0.15.7

# %%
# import wandb


# wandb.login()

# run = wandb.init(
#   project='AG-News'
#   , config = {}
# )

# %% [markdown]
# # Training

# %%
from do_test import do_test
from do_train import do_train
from initialize import initialize
from utils import initialize_logger


def main():
    mode = 'test'

    logger = initialize_logger(configs=configs)
    parameters = initialize(configs=configs, mode='train')

    if mode == 'train':
        do_train(configs=configs, parameters=parameters)
    elif mode == 'validate':
        do_test(configs=configs, parameters=parameters, stage='validate')
    elif mode == 'test':
        do_test(configs=configs, parameters=parameters, stage='test')
    else:
        logger.error(f'There is no mode named {mode}.')
        raise ValueError(f'There is no mode named {mode}.')


if __name__ == '__main__':
    main()
# Out:
# INFO:initialize:Initializing seed to 48763 successfully.
# 2023-07-29 03:18:48,330 - initialize - INFO - Initializing seed to 48763 successfully.
# INFO:initialize:Initializing device to cuda successfully.
# 2023-07-29 03:18:48,584 - initialize - INFO - Initializing device to cuda successfully.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# 2023-07-29 03:18:48,598 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/config.json HTTP/1.1" 200 0
# 2023-07-29 03:18:48,786 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 134595863547040 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# 2023-07-29 03:18:48,791 - filelock - DEBUG - Attempting to acquire lock 134595863547040 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:filelock:Lock 134595863547040 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# 2023-07-29 03:18:48,797 - filelock - DEBUG - Lock 134595863547040 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/config.json HTTP/1.1" 200 570
# 2023-07-29 03:18:48,852 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/config.json HTTP/1.1" 200 570
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 134595863547040 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# 2023-07-29 03:18:48,900 - filelock - DEBUG - Attempting to release lock 134595863547040 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:filelock:Lock 134595863547040 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# 2023-07-29 03:18:48,905 - filelock - DEBUG - Lock 134595863547040 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/model.safetensors HTTP/1.1" 302 0
# 2023-07-29 03:18:48,957 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/model.safetensors HTTP/1.1" 302 0
# DEBUG:filelock:Attempting to acquire lock 134595865263696 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3.lock
# 2023-07-29 03:18:48,964 - filelock - DEBUG - Attempting to acquire lock 134595865263696 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3.lock
# DEBUG:filelock:Lock 134595865263696 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3.lock
# 2023-07-29 03:18:48,970 - filelock - DEBUG - Lock 134595865263696 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cdn-lfs.huggingface.co:443
# 2023-07-29 03:18:48,982 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): cdn-lfs.huggingface.co:443
# DEBUG:urllib3.connectionpool:https://cdn-lfs.huggingface.co:443 "GET /bert-base-uncased/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27model.safetensors%3B+filename%3D%22model.safetensors%22%3B&Expires=1690856026&Policy=_&Signature=p~f-PCS8-jruBIcTjfuxX6rlQ-iXBz~IPc3of1yf67PdfhGikWVViAe9R3wOgGdUCM1adGnPQR8adr4L38gmUESwAvVVH1QoObBDUHEoDjRST6MD91sUY7sa80tpO~X7AhA9fXTGYubTlmDtpopm7qRur~58W3veIXfS14zPe~A6unY0l0F7HJvsHHlG39tdsL0UB1tL-3qE5B9T5YjAbLCxIx-6ja7eVG4o5hU8SnXVltLO4CNJ3O1MQk496b1KKSjU2ci7l9igCxjSei6fRJSQcqE0kjpG5XbT98F6afXYuwJNZALgO-jyub9DfONsVLjSmk7uEIReEdzewJEHEg__&Key-Pair-Id=KVTP0A1DKRTAX HTTP/1.1" 200 440449768
# 2023-07-29 03:18:49,132 - urllib3.connectionpool - DEBUG - https://cdn-lfs.huggingface.co:443 "GET /bert-base-uncased/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27model.safetensors%3B+filename%3D%22model.safetensors%22%3B&Expires=1690856026&Policy=_&Signature=p~f-PCS8-jruBIcTjfuxX6rlQ-iXBz~IPc3of1yf67PdfhGikWVViAe9R3wOgGdUCM1adGnPQR8adr4L38gmUESwAvVVH1QoObBDUHEoDjRST6MD91sUY7sa80tpO~X7AhA9fXTGYubTlmDtpopm7qRur~58W3veIXfS14zPe~A6unY0l0F7HJvsHHlG39tdsL0UB1tL-3qE5B9T5YjAbLCxIx-6ja7eVG4o5hU8SnXVltLO4CNJ3O1MQk496b1KKSjU2ci7l9igCxjSei6fRJSQcqE0kjpG5XbT98F6afXYuwJNZALgO-jyub9DfONsVLjSmk7uEIReEdzewJEHEg__&Key-Pair-Id=KVTP0A1DKRTAX HTTP/1.1" 200 440449768
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 134595865263696 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3.lock
# 2023-07-29 03:18:51,426 - filelock - DEBUG - Attempting to release lock 134595865263696 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3.lock
# DEBUG:filelock:Lock 134595865263696 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3.lock
# 2023-07-29 03:18:51,434 - filelock - DEBUG - Lock 134595865263696 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/68d45e234eb4a928074dfd868cead0219ab85354cc53d20e772753c6bb9169d3.lock
# INFO:initialize:Initializing model to BertWithNN successfully.
# 2023-07-29 03:18:52,666 - initialize - INFO - Initializing model to BertWithNN successfully.
# INFO:initialize:Initializing optimizer to Adam successfully.
# 2023-07-29 03:18:59,329 - initialize - INFO - Initializing optimizer to Adam successfully.
# INFO:initialize:Initializing scheduler to ReduceLROnPlateau successfully.
# 2023-07-29 03:18:59,338 - initialize - INFO - Initializing scheduler to ReduceLROnPlateau successfully.
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/vocab.txt HTTP/1.1" 200 0
# 2023-07-29 03:19:03,600 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/vocab.txt HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 134595863558704 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# 2023-07-29 03:19:03,606 - filelock - DEBUG - Attempting to acquire lock 134595863558704 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:filelock:Lock 134595863558704 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# 2023-07-29 03:19:03,611 - filelock - DEBUG - Lock 134595863558704 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/vocab.txt HTTP/1.1" 200 231508
# 2023-07-29 03:19:03,665 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/vocab.txt HTTP/1.1" 200 231508
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 134595863558704 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# 2023-07-29 03:19:03,728 - filelock - DEBUG - Attempting to release lock 134595863558704 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:filelock:Lock 134595863558704 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# 2023-07-29 03:19:03,732 - filelock - DEBUG - Lock 134595863558704 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/added_tokens.json HTTP/1.1" 404 0
# 2023-07-29 03:19:03,783 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/added_tokens.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/special_tokens_map.json HTTP/1.1" 404 0
# 2023-07-29 03:19:03,834 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/special_tokens_map.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2023-07-29 03:19:03,886 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 134595863552368 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# 2023-07-29 03:19:03,891 - filelock - DEBUG - Attempting to acquire lock 134595863552368 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# DEBUG:filelock:Lock 134595863552368 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# 2023-07-29 03:19:03,896 - filelock - DEBUG - Lock 134595863552368 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/tokenizer_config.json HTTP/1.1" 200 28
# 2023-07-29 03:19:03,945 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/tokenizer_config.json HTTP/1.1" 200 28
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 134595863552368 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# 2023-07-29 03:19:03,984 - filelock - DEBUG - Attempting to release lock 134595863552368 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# DEBUG:filelock:Lock 134595863552368 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# 2023-07-29 03:19:03,991 - filelock - DEBUG - Lock 134595863552368 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/a661b1a138dac6dc5590367402d100765010ffd6.lock
# INFO:initialize:Initializing formatter to AGNewsFormatter successfully.
# 2023-07-29 03:19:04,059 - initialize - INFO - Initializing formatter to AGNewsFormatter successfully.
# INFO:initialize:Initializing train dataloader successfully.
# 2023-07-29 03:19:04,068 - initialize - INFO - Initializing train dataloader successfully.
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/vocab.txt HTTP/1.1" 200 0
# 2023-07-29 03:19:04,881 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/vocab.txt HTTP/1.1" 200 0
# INFO:initialize:Initializing formatter to AGNewsFormatter successfully.
# 2023-07-29 03:19:04,920 - initialize - INFO - Initializing formatter to AGNewsFormatter successfully.
# INFO:initialize:Initializing validation dataloader successfully.
# 2023-07-29 03:19:04,927 - initialize - INFO - Initializing validation dataloader successfully.
# INFO:initialize:Load checkpoint from checkpoint path successfully.
# 2023-07-29 03:19:19,537 - initialize - INFO - Load checkpoint from checkpoint path successfully.
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/vocab.txt HTTP/1.1" 200 0
# 2023-07-29 03:19:20,161 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/vocab.txt HTTP/1.1" 200 0
# INFO:initialize:Initializing formatter to AGNewsFormatter successfully.
# 2023-07-29 03:19:20,201 - initialize - INFO - Initializing formatter to AGNewsFormatter successfully.
# INFO:initialize:Initializing test dataloader successfully.
# 2023-07-29 03:19:20,211 - initialize - INFO - Initializing test dataloader successfully.
# INFO:initialize:Initialize all parameters successfully.
# 2023-07-29 03:19:20,218 - initialize - INFO - Initialize all parameters successfully.
# INFO:initialize:Details of all parameters:
# {'device': device(type='cuda'), 'model': BertWithNN(
#   (lm): Bert(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (activation): Tanh()
#       )
#     )
#   )
#   (classifier): Classifier(
#     (classifier): Sequential(
#       (linear_0): Linear(in_features=768, out_features=384, bias=True)
#       (linear_1): Linear(in_features=384, out_features=192, bias=True)
#       (linear_2): Linear(in_features=192, out_features=4, bias=True)
#       (relu_2): ReLU()
#     )
#   )
#   (criterion): CrossEntropyLoss()
# ), 'trained_epoch': 0, 'test_dataloader': <torch.utils.data.dataloader.DataLoader object at 0x7a69bbea84c0>, 'optimizer': Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# ), 'scheduler': <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7a6a0aa2b730>, 'train_dataloader': <torch.utils.data.dataloader.DataLoader object at 0x7a6a0aab2590>, 'validation_dataloader': <torch.utils.data.dataloader.DataLoader object at 0x7a6a0aa2a0e0>}
# 2023-07-29 03:19:20,223 - initialize - INFO - Details of all parameters:
# {'device': device(type='cuda'), 'model': BertWithNN(
#   (lm): Bert(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (activation): Tanh()
#       )
#     )
#   )
#   (classifier): Classifier(
#     (classifier): Sequential(
#       (linear_0): Linear(in_features=768, out_features=384, bias=True)
#       (linear_1): Linear(in_features=384, out_features=192, bias=True)
#       (linear_2): Linear(in_features=192, out_features=4, bias=True)
#       (relu_2): ReLU()
#     )
#   )
#   (criterion): CrossEntropyLoss()
# ), 'trained_epoch': 0, 'test_dataloader': <torch.utils.data.dataloader.DataLoader object at 0x7a69bbea84c0>, 'optimizer': Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# ), 'scheduler': <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7a6a0aa2b730>, 'train_dataloader': <torch.utils.data.dataloader.DataLoader object at 0x7a6a0aab2590>, 'validation_dataloader': <torch.utils.data.dataloader.DataLoader object at 0x7a6a0aa2a0e0>}
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# INFO:utils:
# +-------+-------+------------+------------------+-----------+-------+
# | epoch | stage | iterations |       time       |   loss    |  lr   |
# +-------+-------+------------+------------------+-----------+-------+
# |   1   | train |   1/6750   | 0:00:04\ 8:51:03 | 0.0526816 | 1e-05 |
# +-------+-------+------------+------------------+-----------+-------+
# +-----+-------+-----+------+-------+-------+-------+-------+
# | MiP |  MiR  | MiF | MiE  |  MaP  |  MaR  |  MaF  |  MaE  |
# +-----+-------+-----+------+-------+-------+-------+-------+
# | 0.8 | 0.267 | 0.4 | 0.75 | 0.792 | 0.263 | 0.378 | 0.406 |
# +-----+-------+-----+------+-------+-------+-------+-------+
#
# 2023-07-29 03:19:24,957 - utils - INFO -
# +-------+-------+------------+------------------+-----------+-------+
# | epoch | stage | iterations |       time       |   loss    |  lr   |
# +-------+-------+------------+------------------+-----------+-------+
# |   1   | train |   1/6750   | 0:00:04\ 8:51:03 | 0.0526816 | 1e-05 |
# +-------+-------+------------+------------------+-----------+-------+
# +-----+-------+-----+------+-------+-------+-------+-------+
# | MiP |  MiR  | MiF | MiE  |  MaP  |  MaR  |  MaF  |  MaE  |
# +-----+-------+-----+------+-------+-------+-------+-------+
# | 0.8 | 0.267 | 0.4 | 0.75 | 0.792 | 0.263 | 0.378 | 0.406 |
# +-----+-------+-----+------+-------+-------+-------+-------+
#
# INFO:utils:
# +-------+-------+------------+------------------+-----------+-------+
# | epoch | stage | iterations |       time       |   loss    |  lr   |
# +-------+-------+------------+------------------+-----------+-------+
# |   1   | train | 1501/6750  | 0:40:31\ 2:21:43 | 0.1535596 | 1e-05 |
# +-------+-------+------------+------------------+-----------+-------+
# +-------+-------+-------+------+-------+-------+-------+------+
# |  MiP  |  MiR  |  MiF  | MiE  |  MaP  |  MaR  |  MaF  | MaE  |
# +-------+-------+-------+------+-------+-------+-------+------+
# | 0.732 | 0.267 | 0.392 | 0.75 | 0.787 | 0.271 | 0.392 | 0.75 |
# +-------+-------+-------+------+-------+-------+-------+------+
#
# 2023-07-29 03:59:52,002 - utils - INFO -
# +-------+-------+------------+------------------+-----------+-------+
# | epoch | stage | iterations |       time       |   loss    |  lr   |
# +-------+-------+------------+------------------+-----------+-------+
# |   1   | train | 1501/6750  | 0:40:31\ 2:21:43 | 0.1535596 | 1e-05 |
# +-------+-------+------------+------------------+-----------+-------+
# +-------+-------+-------+------+-------+-------+-------+------+
# |  MiP  |  MiR  |  MiF  | MiE  |  MaP  |  MaR  |  MaF  | MaE  |
# +-------+-------+-------+------+-------+-------+-------+------+
# | 0.732 | 0.267 | 0.392 | 0.75 | 0.787 | 0.271 | 0.392 | 0.75 |
# +-------+-------+-------+------+-------+-------+-------+------+
#
# INFO:utils:
# +-------+-------+------------+------------------+-----------+-------+
# | epoch | stage | iterations |       time       |   loss    |  lr   |
# +-------+-------+------------+------------------+-----------+-------+
# |   1   | train | 3001/6750  | 1:21:08\ 1:41:21 | 0.1401674 | 1e-05 |
# +-------+-------+------------+------------------+-----------+-------+
# +-------+-------+-------+------+-------+-------+-------+------+
# |  MiP  |  MiR  |  MiF  | MiE  |  MaP  |  MaR  |  MaF  | MaE  |
# +-------+-------+-------+------+-------+-------+-------+------+
# | 0.746 | 0.266 | 0.392 | 0.75 | 0.797 | 0.269 | 0.392 | 0.75 |
# +-------+-------+-------+------+-------+-------+-------+------+
#
# 2023-07-29 04:40:28,287 - utils - INFO -
# +-------+-------+------------+------------------+-----------+-------+
# | epoch | stage | iterations |       time       |   loss    |  lr   |
# +-------+-------+------------+------------------+-----------+-------+
# |   1   | train | 3001/6750  | 1:21:08\ 1:41:21 | 0.1401674 | 1e-05 |
# +-------+-------+------------+------------------+-----------+-------+
# +-------+-------+-------+------+-------+-------+-------+------+
# |  MiP  |  MiR  |  MiF  | MiE  |  MaP  |  MaR  |  MaF  | MaE  |
# +-------+-------+-------+------+-------+-------+-------+------+
# | 0.746 | 0.266 | 0.392 | 0.75 | 0.797 | 0.269 | 0.392 | 0.75 |
# +-------+-------+-------+------+-------+-------+-------+------+
#
# INFO:utils:
# +-------+-------+------------+------------------+-----------+-------+
# | epoch | stage | iterations |       time       |   loss    |  lr   |
# +-------+-------+------------+------------------+-----------+-------+
# |   1   | train | 4501/6750  | 2:01:43\ 1:00:49 | 0.1273348 | 1e-05 |
# +-------+-------+------------+------------------+-----------+-------+
# +-------+-------+-------+------+-------+-------+-------+------+
# |  MiP  |  MiR  |  MiF  | MiE  |  MaP  |  MaR  |  MaF  | MaE  |
# +-------+-------+-------+------+-------+-------+-------+------+
# | 0.752 | 0.266 | 0.393 | 0.75 | 0.799 | 0.269 | 0.393 | 0.75 |
# +-------+-------+-------+------+-------+-------+-------+------+
#
# 2023-07-29 05:21:03,796 - utils - INFO -
# +-------+-------+------------+------------------+-----------+-------+
# | epoch | stage | iterations |       time       |   loss    |  lr   |
# +-------+-------+------------+------------------+-----------+-------+
# |   1   | train | 4501/6750  | 2:01:43\ 1:00:49 | 0.1273348 | 1e-05 |
# +-------+-------+------------+------------------+-----------+-------+
# +-------+-------+-------+------+-------+-------+-------+------+
# |  MiP  |  MiR  |  MiF  | MiE  |  MaP  |  MaR  |  MaF  | MaE  |
# +-------+-------+-------+------+-------+-------+-------+------+
# | 0.752 | 0.266 | 0.393 | 0.75 | 0.799 | 0.269 | 0.393 | 0.75 |
# +-------+-------+-------+------+-------+-------+-------+------+
